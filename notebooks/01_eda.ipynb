# %% [markdown]
# <a href="https://colab.research.google.com/github/abyudh-kattemane/Check/blob/main/notebooks/01_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FinCrime Sentinel — Exploratory Data Analysis
#
#    Week 1 EDA of the IBM AML HI-Small dataset.
#    Part of the FinCrime Sentinel project.
